# %%
### Figure 3C for the PERISCOPE manuscript. ###
### Script by Meraj Ramezani(mramezan@broadinstitute.org) ###
# Import relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import permutations
import matplotlib.font_manager as font_manager


# %matplotlib inline
sns.set_context('poster')
sns.set_style('white')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.5, 's' : 80, 'linewidths':0}

# %%
# Import the Hela DMEM gene level profiles & hits from the hit calling process then subset the gene level profiles for all hits 
df = pd.read_csv('../20210422_6W_CP257_guide_normalized_feature_select_median_merged_ALLBATCHES___DMEM___ALLWELLS_plate_level_gene_aggregated.csv.gz').set_index('Metadata_Foci_Barcode_MatchedTo_GeneCode')
comp_spef_hits = pd.read_csv('../Fig3_A_B/cp257_dmem_plate_level_median_per_feat_sig_genes_5_fdr_compartment_specific_hits.csv').rename(columns={'Unnamed: 0':'Gene'}).set_index('Gene')
whole_cell_hits = pd.read_csv('../Fig3_A_B/cp257_dmem_plate_level_median_per_feat_sig_genes_5_fdr_whole_cell_hits.csv').rename(columns={'Unnamed: 0':'Gene'}).set_index('Gene')
hit_list = list(comp_spef_hits.index) + list(whole_cell_hits.index)
df_hits = df.loc[hit_list]
df_hits
# Out:
#                                           Cells_AreaShape_CentralMoment_0_3  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                            -0.003687
# AADAT                                                              0.010149
# AAGAB                                                              0.001373
# AARSD1                                                             0.011580
# AASDHPPT                                                           0.010061
# ...                                                                     ...
# ZP3                                                                0.002234
# ZPR1                                                               0.000413
# ZSWIM8                                                             0.008489
# ZYX                                                               -0.001728
# ZZEF1                                                             -0.002265
#
#                                           Cells_AreaShape_CentralMoment_1_0  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                            -0.001517
# AADAT                                                             -0.050984
# AAGAB                                                             -0.073191
# AARSD1                                                            -0.099327
# AASDHPPT                                                          -0.008188
# ...                                                                     ...
# ZP3                                                                0.023157
# ZPR1                                                              -0.015735
# ZSWIM8                                                             0.287793
# ZYX                                                                0.127841
# ZZEF1                                                             -0.025710
#
#                                           Cells_AreaShape_CentralMoment_1_2  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                            -0.024211
# AADAT                                                             -0.000033
# AAGAB                                                              0.005038
# AARSD1                                                            -0.017418
# AASDHPPT                                                           0.016220
# ...                                                                     ...
# ZP3                                                                0.012874
# ZPR1                                                              -0.015433
# ZSWIM8                                                            -0.001380
# ZYX                                                               -0.003141
# ZZEF1                                                             -0.010416
#
#                                           Cells_AreaShape_CentralMoment_2_1  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                            -0.002230
# AADAT                                                             -0.011308
# AAGAB                                                             -0.008009
# AARSD1                                                             0.022201
# AASDHPPT                                                          -0.005553
# ...                                                                     ...
# ZP3                                                                0.013057
# ZPR1                                                               0.001812
# ZSWIM8                                                             0.012269
# ZYX                                                               -0.000141
# ZZEF1                                                             -0.026102
#
#                                           Cells_AreaShape_CentralMoment_2_3  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                            -0.000985
# AADAT                                                              0.000147
# AAGAB                                                             -0.000422
# AARSD1                                                             0.004731
# AASDHPPT                                                           0.001298
# ...                                                                     ...
# ZP3                                                                0.000447
# ZPR1                                                              -0.000215
# ZSWIM8                                                             0.002484
# ZYX                                                                0.000653
# ZZEF1                                                              0.000046
#
#                                           Cells_AreaShape_Compactness  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                       0.048217
# AADAT                                                       -0.390320
# AAGAB                                                       -0.110842
# AARSD1                                                      -0.048940
# AASDHPPT                                                    -0.359410
# ...                                                               ...
# ZP3                                                         -0.268155
# ZPR1                                                        -0.551765
# ZSWIM8                                                      -0.070610
# ZYX                                                         -0.057800
# ZZEF1                                                       -0.036503
#
#                                           Cells_AreaShape_Eccentricity  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                       -0.247624
# AADAT                                                         0.192267
# AAGAB                                                         0.408275
# AARSD1                                                       -0.060862
# AASDHPPT                                                     -0.452070
# ...                                                                ...
# ZP3                                                          -0.032118
# ZPR1                                                         -0.001942
# ZSWIM8                                                       -0.190660
# ZYX                                                          -0.026700
# ZZEF1                                                         0.055400
#
#                                           Cells_AreaShape_Extent  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                 -0.385445
# AADAT                                                   0.127596
# AAGAB                                                   0.010436
# AARSD1                                                 -0.170685
# AASDHPPT                                               -0.113907
# ...                                                          ...
# ZP3                                                    -0.136975
# ZPR1                                                    0.403800
# ZSWIM8                                                 -0.032445
# ZYX                                                     0.050321
# ZZEF1                                                   0.115180
#
#                                           Cells_AreaShape_FormFactor  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                     -0.181542
# AADAT                                                       0.360045
# AAGAB                                                       0.014049
# AARSD1                                                     -0.057970
# AASDHPPT                                                    0.367390
# ...                                                              ...
# ZP3                                                         0.203412
# ZPR1                                                        0.569805
# ZSWIM8                                                     -0.026930
# ZYX                                                        -0.057195
# ZZEF1                                                      -0.083702
#
#                                           Cells_AreaShape_HuMoment_1  ...  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode                              ...
# A4GALT                                                     -0.310485  ...
# AADAT                                                      -0.037015  ...
# AAGAB                                                      -0.013480  ...
# AARSD1                                                     -0.051002  ...
# AASDHPPT                                                   -0.194975  ...
# ...                                                              ...  ...
# ZP3                                                        -0.126557  ...
# ZPR1                                                       -0.217560  ...
# ZSWIM8                                                     -0.222235  ...
# ZYX                                                        -0.178050  ...
# ZZEF1                                                      -0.045825  ...
#
#                                           Nuclei_Texture_SumVariance_DAPI_Painting_10_02_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                            -0.205460
# AADAT                                                                              0.035560
# AAGAB                                                                             -0.364305
# AARSD1                                                                            -0.251240
# AASDHPPT                                                                          -0.160485
# ...                                                                                     ...
# ZP3                                                                               -0.166314
# ZPR1                                                                               0.242875
# ZSWIM8                                                                            -0.109120
# ZYX                                                                                0.126379
# ZZEF1                                                                             -0.068458
#
#                                           Nuclei_Texture_SumVariance_DAPI_Painting_10_03_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                            -0.124003
# AADAT                                                                              0.096781
# AAGAB                                                                             -0.374600
# AARSD1                                                                            -0.230710
# AASDHPPT                                                                          -0.184115
# ...                                                                                     ...
# ZP3                                                                               -0.231420
# ZPR1                                                                               0.536345
# ZSWIM8                                                                             0.011316
# ZYX                                                                               -0.020406
# ZZEF1                                                                             -0.202371
#
#                                           Nuclei_Texture_SumVariance_Mito_10_03_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                    -0.061160
# AADAT                                                                      0.002351
# AAGAB                                                                     -0.045733
# AARSD1                                                                    -0.123475
# AASDHPPT                                                                  -0.156485
# ...                                                                             ...
# ZP3                                                                       -0.150015
# ZPR1                                                                       0.335195
# ZSWIM8                                                                     0.010509
# ZYX                                                                       -0.070986
# ZZEF1                                                                     -0.158160
#
#                                           Nuclei_Texture_SumVariance_Mito_5_01_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                   -0.064534
# AADAT                                                                     0.014290
# AAGAB                                                                    -0.048909
# AARSD1                                                                   -0.036832
# AASDHPPT                                                                 -0.030092
# ...                                                                            ...
# ZP3                                                                      -0.063093
# ZPR1                                                                      0.045955
# ZSWIM8                                                                    0.018169
# ZYX                                                                      -0.017315
# ZZEF1                                                                    -0.057480
#
#                                           Nuclei_Texture_SumVariance_Phalloidin_10_01_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                          -0.158805
# AADAT                                                                           -0.047730
# AAGAB                                                                           -0.093886
# AARSD1                                                                          -0.078641
# AASDHPPT                                                                        -0.156475
# ...                                                                                   ...
# ZP3                                                                             -0.058868
# ZPR1                                                                            -0.013645
# ZSWIM8                                                                          -0.121815
# ZYX                                                                             -0.124905
# ZZEF1                                                                           -0.109966
#
#                                           Nuclei_Texture_SumVariance_Phalloidin_10_03_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                          -0.175165
# AADAT                                                                           -0.055333
# AAGAB                                                                           -0.073781
# AARSD1                                                                          -0.171565
# AASDHPPT                                                                        -0.236350
# ...                                                                                   ...
# ZP3                                                                             -0.073555
# ZPR1                                                                             0.059679
# ZSWIM8                                                                          -0.111510
# ZYX                                                                             -0.129980
# ZZEF1                                                                           -0.057180
#
#                                           Nuclei_Texture_SumVariance_Phalloidin_5_01_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                         -0.100943
# AADAT                                                                          -0.027467
# AAGAB                                                                          -0.127453
# AARSD1                                                                         -0.146525
# AASDHPPT                                                                       -0.165520
# ...                                                                                  ...
# ZP3                                                                            -0.056141
# ZPR1                                                                           -0.001273
# ZSWIM8                                                                         -0.119964
# ZYX                                                                            -0.075756
# ZZEF1                                                                          -0.089847
#
#                                           Nuclei_Texture_SumVariance_WGA_10_01_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                   -0.116820
# AADAT                                                                    -0.030975
# AAGAB                                                                    -0.269980
# AARSD1                                                                   -0.317805
# AASDHPPT                                                                 -0.378370
# ...                                                                            ...
# ZP3                                                                      -0.257935
# ZPR1                                                                      0.092637
# ZSWIM8                                                                   -0.045433
# ZYX                                                                       0.019228
# ZZEF1                                                                    -0.457715
#
#                                           Nuclei_Texture_SumVariance_WGA_10_03_256  \
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                   -0.127088
# AADAT                                                                    -0.054734
# AAGAB                                                                     0.009450
# AARSD1                                                                   -0.210240
# AASDHPPT                                                                 -0.270330
# ...                                                                            ...
# ZP3                                                                      -0.285295
# ZPR1                                                                     -0.032070
# ZSWIM8                                                                    0.318355
# ZYX                                                                      -0.261445
# ZZEF1                                                                    -0.409825
#
#                                           Nuclei_Texture_SumVariance_WGA_5_01_256
# Metadata_Foci_Barcode_MatchedTo_GeneCode
# A4GALT                                                                  -0.208700
# AADAT                                                                   -0.066406
# AAGAB                                                                   -0.024553
# AARSD1                                                                  -0.273045
# AASDHPPT                                                                -0.201435
# ...                                                                           ...
# ZP3                                                                     -0.359115
# ZPR1                                                                    -0.005467
# ZSWIM8                                                                  -0.044189
# ZYX                                                                      0.002777
# ZZEF1                                                                   -0.516860
#
# [4681 rows x 1597 columns]

# %%
# Calculate correlation between all gene pairs and create a dictionory of gene pairs/correlation
df_hits_corr = df_hits.T.corr()
genes = list(df_hits_corr.index)
corr_dic = {}
for gene1 in genes:
    for gene2 in genes:
        if len(frozenset([gene1,gene2])) == 1 :
            continue
        else:    
            corr_dic[frozenset([gene1,gene2])]=(df_hits_corr.loc[gene1,gene2])
        
print(len(corr_dic))
# Out:
# 10953540

# %%
# Input the protein clusters from the CORUM3.0 database and subset the human clusters
ppi_data = pd.read_csv('../Input_files/allComplexes 2.txt',sep = '\t')
ppi_data_h = ppi_data[ppi_data['Organism'] == "Human"]
ppi_data_h
# Out:
#       ComplexID                                ComplexName Organism  \
# 0             1                         BCL6-HDAC4 complex    Human
# 1             2                         BCL6-HDAC5 complex    Human
# 2             3                         BCL6-HDAC7 complex    Human
# 3             4      Multisubunit ACTR coactivator complex    Human
# 5            10                        Condensin I complex    Human
# ...         ...                                        ...      ...
# 4267       7586                         FOXO1-ESR1 complex    Human
# 4268       7587                    APP(AICD)-FOXO3 complex    Human
# 4269       7588                    APP(AICD)-FOXO1 complex    Human
# 4270       7589                    APP(AICD)-FOXO4 complex    Human
# 4272       7593  AKAP13-MAP2K3-MAP3K20-MAPK14-PKN1 complex    Human
#
#                       Synonyms  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 5        13S condensin complex
# ...                        ...
# 4267         FKHR-ESRA complex
# 4268  APP(AICD)-FOXO3a complex
# 4269                      None
# 4270                      None
# 4272                      None
#
#                                               Cell line  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 5                                                  None
# ...                                                 ...
# 4267  human hepatocyte carcinoma HepG2 cells; MCF-7 ...
# 4268                      HEK 293T cells; SY-SH5Y cells
# 4269                      HEK 293T cells; SY-SH5Y cells
# 4270                      HEK 293T cells; SY-SH5Y cells
# 4272                                       HEK293 cells
#
#                    subunits(UniProt IDs)          subunits(Entrez IDs)  \
# 0                          P41182;P56524                      604;9759
# 1                          P41182;Q9UQL6                     604;10014
# 2                          P41182;Q8WUI4                     604;51564
# 3            Q09472;Q92793;Q92831;Q9Y6Q9           2033;1387;8850;8202
# 5     O95347;Q15003;Q15021;Q9BPX3;Q9NTJ3  10592;23397;9918;64151;10051
# ...                                  ...                           ...
# 4267                       P03372;Q12778                     2099;2308
# 4268                       O43524;P05067                      2309;351
# 4269                       P05067;Q12778                      351;2308
# 4270                       P05067;P98177                      351;4303
# 4272  P46734;Q12802;Q16512;Q16539;Q9NYL2    5606;11214;5585;1432;51776
#
#                     Protein complex purification method  \
# 0                MI:0007-anti tag coimmunoprecipitation
# 1                MI:0007-anti tag coimmunoprecipitation
# 2                MI:0007-anti tag coimmunoprecipitation
# 3     MI:0004-affinity chromatography technologies;M...
# 5     MI:0004-affinity chromatography technologies;M...
# ...                                                 ...
# 4267               MI:0096-pull down;MI:0018-two hybrid
# 4268                      MI:0019-coimmunoprecipitation
# 4269                      MI:0019-coimmunoprecipitation
# 4270                      MI:0019-coimmunoprecipitation
# 4272                      MI:0019-coimmunoprecipitation
#
#                                                   GO ID  \
# 0     GO:0006265;GO:0045892;GO:0051276;GO:0030183;GO...
# 1     GO:0006265;GO:0045892;GO:0051276;GO:0030183;GO...
# 2     GO:0006265;GO:0045892;GO:0051276;GO:0030183;GO...
# 3                      GO:0045893;GO:0023052;GO:0005634
# 5     GO:0000279;GO:0007067;GO:0030261;GO:0007059;GO...
# ...                                                 ...
# 4267                              GO:0035257;GO:0030331
# 4268  GO:0005737;GO:0008219;GO:0006979;GO:0005634;GO...
# 4269                   GO:0008219;GO:0005737;GO:0006915
# 4270                   GO:0008219;GO:0005737;GO:0006915
# 4272                                         GO:0000165
#
#                                          GO description  \
# 0     DNA topological change;negative regulation of ...
# 1     DNA topological change;negative regulation of ...
# 2     DNA topological change;negative regulation of ...
# 3     positive regulation of transcription, DNA-temp...
# 5     M phase;mitotic nuclear division;chromosome co...
# ...                                                 ...
# 4267  nuclear hormone receptor binding;estrogen rece...
# 4268  cytoplasm;cell death;response to oxidative str...
# 4269             cell death;cytoplasm;apoptotic process
# 4270             cell death;cytoplasm;apoptotic process
# 4272                                       MAPK cascade
#
#                                               FunCat ID  \
# 0     10.01.09.05;11.02.03.04.03;42.10.03;43.03.07.0...
# 1     10.01.09.05;11.02.03.04.03;42.10.03;43.03.07.0...
# 2     10.01.09.05;11.02.03.04.03;42.10.03;43.03.07.0...
# 3                            11.02.03.04.01;30.01;70.10
# 5     10.03.01.01.11;10.03.04.03;10.03.04.05;42.10.0...
# ...                                                 ...
# 4267                                               None
# 4268                70.03;40.10;32.01.01;70.10;40.10.02
# 4269                               40.10;70.03;40.10.02
# 4270                               40.10;70.03;40.10.02
# 4272                                     30.01.05.01.03
#
#                                      FunCat description  \
# 0     DNA conformation modification (e.g. chromatin)...
# 1     DNA conformation modification (e.g. chromatin)...
# 2     DNA conformation modification (e.g. chromatin)...
# 3     transcription activation;cellular signalling;n...
# 5     M phase;chromosome condensation;chromosome seg...
# ...                                                 ...
# 4267                                               None
# 4268  cytoplasm;cell death;oxidative stress response...
# 4269  cell death;cytoplasm;apoptosis (type I program...
# 4270  cell death;cytoplasm;apoptosis (type I program...
# 4272                                     MAPKKK cascade
#
#                     subunits(Gene name)  \
# 0                            BCL6;HDAC4
# 1                            BCL6;HDAC5
# 2                            BCL6;HDAC7
# 3              EP300;CREBBP;KAT2B;NCOA3
# 5          SMC2;NCAPH;NCAPD2;NCAPG;SMC4
# ...                                 ...
# 4267                         ESR1;FOXO1
# 4268                          FOXO3;APP
# 4269                          APP;FOXO1
# 4270                          APP;FOXO4
# 4272  MAP2K3;AKAP13;PKN1;MAPK14;MAP3K20
#
#                                Subunits comment  PubMed ID  \
# 0                                          None   11929873
# 1                                          None   11929873
# 2                                          None   11929873
# 3                                          None    9267036
# 5                                          None   11136719
# ...                                         ...        ...
# 4267                                       None   11353774
# 4268  AICD is a small APP intracellular domain.   24832605
# 4269  AICD is a small APP intracellular domain.   24832605
# 4270  AICD is a small APP intracellular domain.   24832605
# 4272                                       None   21224381
#
#                                         Complex comment Disease comment  \
# 0     Transcriptional repression by BCL6 is thought ...            None
# 1     Transcriptional repression by BCL6 is thought ...            None
# 2     Transcriptional repression by BCL6 is thought ...            None
# 3     Cofactor ACTR binds directly nuclear receptors...            None
# 5                                                  None            None
# ...                                                 ...             ...
# 4267  FKHR interacts with ERalpha in an E2-dependent...            None
# 4268  In human cells, AICD physically interacts with...            None
# 4269  In human cells, AICD physically interacts with...            None
# 4270  In human cells, AICD physically interacts with...            None
# 4272  Silencing of AKAP13 expression  specifically r...            None
#
#                                      SWISSPROT organism  \
# 0             Homo sapiens (Human);Homo sapiens (Human)
# 1             Homo sapiens (Human);Homo sapiens (Human)
# 2             Homo sapiens (Human);Homo sapiens (Human)
# 3     Homo sapiens (Human);Homo sapiens (Human);Homo...
# 5     Homo sapiens (Human);Homo sapiens (Human);Homo...
# ...                                                 ...
# 4267          Homo sapiens (Human);Homo sapiens (Human)
# 4268          Homo sapiens (Human);Homo sapiens (Human)
# 4269          Homo sapiens (Human);Homo sapiens (Human)
# 4270          Homo sapiens (Human);Homo sapiens (Human)
# 4272  Homo sapiens (Human);Homo sapiens (Human);Homo...
#
#                                 subunits(Gene name syn)  \
# 0                       BCL5 LAZ3 ZBTB27 ZNF51;KIAA0288
# 1                       BCL5 LAZ3 ZBTB27 ZNF51;KIAA0600
# 2                         BCL5 LAZ3 ZBTB27 ZNF51;HDAC7A
# 3        P300;CBP;PCAF;AIB1, BHLHE42, RAC3, TRAM1, ACTR
# 5     CAPE SMC2L1;BRRN BRRN1 CAPH KIAA0074;CAPD2 CNA...
# ...                                                 ...
# 4267                           ESRA, NR3A1;FKHR, FOXO1A
# 4268      FKHRL1, FOXO3A;Amyloid beta precursor protein
# 4269        Amyloid beta precursor protein;FKHR, FOXO1A
# 4270      Amyloid beta precursor protein;AFX AFX1 MLLT7
# 4272  MEK3,MKK3,PRKMK3,SKK2;BRX,HT31,LBC;PAK1,PKN,PR...
#
#                                  subunits(Protein name)
# 0       B-cell lymphoma 6 protein;Histone deacetylase 4
# 1       B-cell lymphoma 6 protein;Histone deacetylase 5
# 2       B-cell lymphoma 6 protein;Histone deacetylase 7
# 3     Histone acetyltransferase p300;CREB-binding pr...
# 5     Structural maintenance of chromosomes protein ...
# ...                                                 ...
# 4267          Estrogen receptor;Forkhead box protein O1
# 4268    Forkhead box protein O3;Amyloid beta A4 protein
# 4269    Amyloid beta A4 protein;Forkhead box protein O1
# 4270    Amyloid beta A4 protein;Forkhead box protein O4
# 4272  Dual specificity mitogen-activated protein kin...
#
# [2916 rows x 20 columns]

# %%
# Create a list of protein clusters with all complexes that had at least 66% of genes represented within the Hela DMEM WGS hits
cluster_count = 0
hit_cluster_list_list = []
hit_set = set()
for i in range(len(ppi_data_h)):
    cluster = ppi_data_h.iloc[i]['subunits(Gene name)'].split(';')
    count = 0
    hit_cluster_list = []
    for g in cluster:
        if g in genes:
            count += 1
            hit_set.add(g)
            hit_cluster_list.append(g)
    if (count/len(cluster)) >= 0.66:
        cluster_count += 1
    if hit_cluster_list and (count/len(cluster)) >= 0.66:
        hit_cluster_list_list.append(hit_cluster_list)
print(len(hit_set),cluster_count,len(hit_cluster_list_list))
# Out:
# 1450 744 744

# %%
# Assign correlations to hit gene pairs
hit_pair_set = set()
for l in hit_cluster_list_list:
    for c in list(permutations(l,2)):
        hit_pair_set.add(frozenset(c))

hit_corr_dic = {}
for s in hit_pair_set:
    hit_corr_dic[s] = corr_dic[s]

print(' Number of hit pairs',len(hit_pair_set),'\n',
      'Number of hit pairs with correlation',len(hit_corr_dic))
# Out:
#  Number of hit pairs 5822
#  Number of hit pairs with correlation 5822

# %%
# Plot CORUM gene pair correlation distribution for Fig 3C
sns.set_theme(style="white",rc = {'axes.linewidth': 0.7,'xtick.labelsize':17,'ytick.labelsize':17})


fig, ax = plt.subplots(figsize=(7,4))

all_corr = list(corr_dic.values())
cluster_corr = list(hit_corr_dic.values())

sns.histplot(all_corr ,color='b' ,stat= 'percent' ,bins= 100, kde=True, line_kws={'lw':1.4} , alpha=0.5,ax = ax);
sns.histplot(cluster_corr ,color='r' ,stat= 'percent' ,bins= 100, kde=True, line_kws={'lw':1.4} ,alpha=0.5,ax = ax);


ax.set_ylabel('Gene pair frequency',size=17)
ax.set_xlabel('Correlation of profiles',size=17)

font = font_manager.FontProperties(size=14)
ax.legend(['Hit gene pairs','Hit gene pairs in CORUM complex'],loc='upper left',bbox_to_anchor=(0.0,1.2),frameon=False,prop=font )

sns.despine(top = True)



fig.savefig('Fig3_C_Hela_DMEM_CORUM_gene_pair_correlation_distribution.png', dpi=300,facecolor='w', edgecolor='w', bbox_inches='tight')
plt.show()
